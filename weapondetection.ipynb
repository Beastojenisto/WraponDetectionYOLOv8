# %% [markdown]
# # **Importing Ultralytics**

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5432.0/8062.4 GB disk)

# %% [markdown]
# # **Creating The Config file in the current directory**

# %%
import yaml

data_yaml = dict(
    train ='/kaggle/working/Weapon-Detection-2//train',
    val ='/kaggle/working/Weapon-Detection-2//valid',
    test='/kaggle/working/Weapon-Detection-2//test',
    nc = 3,
    names =['gun','guns','handgun']
)

with open('data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat data.yaml
# Out:
# {names: [gun, guns, handgun], nc: 3, test: /kaggle/working/Weapon-Detection-2//test,
#   train: /kaggle/working/Weapon-Detection-2//train, val: /kaggle/working/Weapon-Detection-2//valid}

# %% [markdown]
# # **Training the YOLOv8 large model**

# %%
from ultralytics import YOLO
model = YOLO('yolov8l.pt')
model.train(data='/kaggle/working/data.yaml', epochs=50, imgsz=416, batch=16,exist_ok=True)
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 264MB/s]
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %% [markdown]
# # **Visualizing the model's prediction on validation dataset**

# %%
from IPython.display import Image

Image('/kaggle/working/runs/detect/train/val_batch1_pred.jpg')
